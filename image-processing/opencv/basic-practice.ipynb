# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

cv2.samples.addSamplesDataSearchPath('samples/data')

# %%
img = cv2.imread(cv2.samples.findFile('messi5.jpg'))

print(type(img))

plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# [ WARN:0@2153.089] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/core/src/utils/samples.cpp (61) findFile cv::samples::findFile('messi5.jpg') => 'samples/data/messi5.jpg'

# %%
print(img.shape[0]) # hight
print(img.shape[1]) # width
print(img.size)
# Out:
# 342
# 548
# 562248

# %%
# accessing a pixel  
px = img[100, 100]
print(px)
# Out:
# [157 166 200]

# %%
blue = img[100, 100, 0]
print(blue)
# Out:
# 157

# %%
img = cv2.imread(cv2.samples.findFile('messi5.jpg'), 0)
print(type(img))

plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# [ WARN:0@2047.500] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/core/src/utils/samples.cpp (61) findFile cv::samples::findFile('messi5.jpg') => 'samples/data/messi5.jpg'
